# %%
dataset_path = "../../nechkasova-tokenizer/assets/annotated-corpus/train"

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/onechkasova/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
import string

def read_data(file_path):
    with open(file_path, encoding="ISO-8859-1") as file:
        lines = file.readlines()
    return lines

def clean_text(text):
    text = re.sub(f"[{re.escape(string.punctuation)}]", '', text)
    return text.lower()

# %%
def process_file(file_path):
    lines = read_data(file_path)
    tokens = []

    for line in lines:
        if line.strip():
            try:
                token, stem, lemma = line.strip().split('\t')
            except:
                continue
            cleaned_token = clean_text(token)
            if cleaned_token and cleaned_token not in stop_words:
                tokens.append(cleaned_token)
    
    return tokens

# %%
import os

def process_directory(directory_path):
    all_tokens = []

    for root, dirs, files in os.walk(directory_path):
        for file in files:
            file_path = os.path.join(root, file)
            print(f"Process file {file_path}")
            tokens = process_file(file_path)
            all_tokens.append(tokens)

    return all_tokens

# %%
tokens = process_directory(dataset_path)
# print(len(tokens))

print(tokens[0])
# Out:
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75384.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75390.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75421.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76114.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76100.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76316.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76302.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75958.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76289.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75970.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75964.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76262.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76504.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76510.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76276.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76048.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76060.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76074.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76075.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76061.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76049.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76511.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76277.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76263.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76505.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75965.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75971.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76288.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75959.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76303.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76317.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75408.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76101.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76115.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75391.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75385.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75393.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75422.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76103.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76117.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75378.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76498.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76329.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76301.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76315.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75967.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76249.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75998.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76275.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76513.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76507.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76261.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76077.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76063.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76062.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76076.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76089.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76506.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76260.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76274.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76512.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75999.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76248.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75966.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76314.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76300.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76328.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76499.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76116.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75379.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76102.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75386.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75392.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75396.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75382.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76106.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75369.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76112.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76489.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76304.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76310.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76338.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75962.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75976.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76516.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76270.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76264.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76502.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75989.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76258.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76099.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76066.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76067.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76073.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76098.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76259.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75988.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76265.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76503.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76517.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76271.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75977.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75963.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76339.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76311.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76305.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76488.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76113.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76107.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75381.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75395.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76111.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76105.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76139.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76313.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76307.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75975.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75961.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76298.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76501.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76267.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76273.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76515.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76529.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76065.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76059.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76058.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76070.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76064.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76528.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76272.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76514.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76500.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76266.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75948.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76299.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75960.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75974.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76306.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76312.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76138.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76104.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76110.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75394.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76188.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76177.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76163.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75873.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76349.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76413.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76361.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75913.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75907.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76229.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76201.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76215.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76003.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76016.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76002.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76214.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76200.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76228.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75912.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76360.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75899.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76348.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76162.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76176.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76189.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76148.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76160.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76174.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76376.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75938.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75904.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75910.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76216.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76202.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76028.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76014.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76000.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76001.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76015.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76029.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76203.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76217.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75911.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75905.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76377.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76363.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76175.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76161.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76149.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76165.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76171.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76159.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76398.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75901.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75915.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75929.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76213.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76207.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76011.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76005.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76039.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76038.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76004.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76010.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76206.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76212.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75928.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75914.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75900.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76428.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76400.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75874.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76158.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76170.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76164.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76199.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76172.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76166.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75876.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76364.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75889.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75916.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75902.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76204.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76210.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76238.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76006.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76012.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76013.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76007.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76239.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76211.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76205.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75903.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75917.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76359.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75888.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76365.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76371.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76417.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75877.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76167.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76173.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76198.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76195.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76181.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76156.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76142.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76354.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75885.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75891.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76340.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76426.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75926.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76208.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76220.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76234.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76022.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76036.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76037.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76023.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76235.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76221.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76209.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75927.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75933.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76341.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75890.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76427.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75884.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76143.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76157.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76180.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76194.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76182.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76196.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76169.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76141.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76155.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76394.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76425.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75892.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76343.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76357.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75886.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75919.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75925.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76237.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76223.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76035.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76021.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76020.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76034.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76008.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76222.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76236.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75930.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75924.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75918.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75887.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76356.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76424.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76342.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75893.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76154.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76140.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76168.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76197.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76183.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76187.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76193.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76144.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76150.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76178.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76391.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76346.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76352.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75883.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75920.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76232.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76226.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76030.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76024.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76018.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76019.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76025.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76031.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76227.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76233.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75909.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75921.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75882.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76353.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76347.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75896.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76390.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76179.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76145.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76192.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76186.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76190.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76184.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76153.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76147.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76392.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76351.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75880.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75894.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76345.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76379.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75937.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75923.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76225.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76231.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76219.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76027.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76033.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76032.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76026.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76218.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76230.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76224.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75922.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75936.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76378.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76344.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75895.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75881.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76350.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76393.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76146.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76152.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76185.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76191.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75399.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75400.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75414.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75372.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76135.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76121.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76492.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76486.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76337.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76323.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75979.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76280.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75951.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75945.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76294.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75992.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76243.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76525.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76531.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76257.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75986.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76082.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76096.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76069.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76055.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76040.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76068.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76097.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76083.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76530.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75987.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76256.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76242.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75993.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76524.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76518.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76295.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75944.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75950.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76281.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75978.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76322.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76336.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76487.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76493.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76120.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76134.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75373.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75367.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75401.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75398.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75371.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75417.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75403.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75365.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76136.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76485.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76491.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76308.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76320.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76334.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75946.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76297.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76283.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75952.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76268.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76254.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75985.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76532.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76526.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76240.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76095.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76056.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76042.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76043.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76057.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76080.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76094.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76527.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76241.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75990.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75984.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76255.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76533.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76269.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/75953.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76282.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76296.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76335.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76321.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76309.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.politics.mideast/76490.tsv
# ...
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/82760.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/82774.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83442.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83456.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83481.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83495.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84113.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83668.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83867.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83708.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84067.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84073.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83522.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83523.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84072.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83899.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83669.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84106.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83494.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83457.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/82775.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/82777.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83469.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/82763.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83455.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83441.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83496.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/82788.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83482.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83643.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83680.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84070.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83509.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83535.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/82818.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/82819.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83520.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83508.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83736.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83722.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84071.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83681.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83642.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84105.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83483.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83497.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83440.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83454.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83468.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/82776.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84360.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83816.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83745.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83786.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83547.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84200.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83591.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83585.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84201.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84229.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83744.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83803.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83817.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84188.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83624.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83630.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84149.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84175.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83829.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83801.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83975.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83544.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84203.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83593.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83587.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83586.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83592.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84202.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84558.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83974.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83790.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84014.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83800.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83828.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84174.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84148.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83627.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84399.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84170.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84164.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83623.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84158.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84004.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83582.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83568.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83781.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83795.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84011.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83811.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83805.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83622.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84165.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84398.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83608.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83620.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83807.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84198.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83998.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83740.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83783.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83581.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83594.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83741.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83999.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84006.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84199.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83812.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83621.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83609.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/84358.tsv
# Process file ../../nechkasova-tokenizer/assets/annotated-corpus/train/talk.religion.misc/83437.tsv
# ['flaxfrejteknikumuuse', 'jonas', 'flygare', 'subject', '18', 'israelis', 'murdered', 'march', 'organization', 'dept', 'control', 'teknikum', 'uppsala', 'lines', '184', 'flax93apr4151411frejteknikumuuse', '1993apr51254198157thundermcrcimmcgilledu', 'nntp', 'posting', 'host', 'frej', 'teknikum', 'uu', 'se', 'reply', 'hasanmcrcimmcgilledu', 'message', 'mon', '5', 'apr', '93', '12', '54', '19', 'gmt', 'article', '1993apr51254198157thundermcrcimmcgilledu', 'hasanmcrcimmcgilledu', 'writes', 'small', 'refresh', 'hasan', 'got', 'track', 'article', 'flax93apr4151411frejteknikumuuse', 'flaxfrejteknikumuuse', 'jonas', 'flygare', 'writes', 'article', '1993apr318273817587thundermcrcimmcgilledu', 'hasanmcrcimmcgilledu', 'writes', 'article', 'flax93apr3142133frejteknikumuuse', 'flaxfrejteknikumuuse', 'jonas', 'flygare', 'writes', 'get', 'impression', 'hasan', 'realized', 'goofed', 'trying', 'drop', 'thread', 'let', 'might', 'save', 'miniscule', 'portion', 'sorry', 'face', 'really', 'since', 'logical', 'person', 'likes', 'furthering', 'name', 'calling', 'started', 'trashing', 'article', 'contains', 'abuses', 'without', 'responding', 'sometimes', 'even', 'reading', 'articles', 'written', 'acquired', 'bad', 'habits', 'bad', 'company', 'ah', 'followup', 'subject', 'way', 'never', 'bothered', 'responding', 'name', 'calling', 'hence', 'assumption', 'feel', 'might', 'answer', 'refresh', 'memory', 'human', 'right', 'issue', 'area', 'apply', 'palestinians', 'also', 'claim', 'thing', 'forfeiting', 'human', 'right', 'possible', 'explain', 'rest', 'us', 'exist', 'thing', 'use', 'logic', 'convince', 'us', 'golden', 'chance', 'jonas', 'flygare', 'well', 'ok', 'let', 'see', 'master', 'wisdom', 'mr jonas', 'flygare', 'wrote', 'wisdomely', 'responded', 'calling', 'names', 'giving', 'title', 'first', 'read', 'paragraph', 'accept', 'title', 'order', 'let', 'get', 'um', 'well', 'debate', 'master', 'wisdom', 'writes', '1993mar31101957frejteknikumuuse', 'hasan', 'flax', 'hasan', 'case', 'didnot', 'know', 'palestineans', '18', 'months', 'coming', 'back', 'agree', 'give', 'palestineans', 'human', 'rights', 'afterall', 'human', 'rights', 'arenot', 'negotiable', 'correct', 'wrong', 'right', 'one', 'life', 'also', 'human', 'right', 'apply', 'palestinians', 'everybody', 'right', 'however', 'killer', 'kills', 'giving', 'willingly', 'unwillingly', 'life', 'right', 'society', 'society', 'represented', 'goverment', 'would', 'exercise', 'duty', 'depriving', 'killer', 'life', 'right', 'right', 'israel', 'kill', 'people', 'kill', 'israelis', 'old', 'eye', 'eye', 'thinking', 'funny', 'thought', 'modern', 'legal', 'systems', 'made', 'counter', 'exactly', 'expect', 'tell', 'tell', 'master', 'wsidom', 'insist', 'giving', 'names', 'titles', 'ask', 'could', 'least', 'spell', 'correctly', 'sigh', 'intentionally', 'neglecting', 'important', 'fact', 'whole', 'israeli', 'presence', 'occupied', 'territories', 'illegitimate', 'hence', 'actions', 'courts', 'laws', 'illegitimate', 'ground', 'occupied', 'territories', 'neglecting', 'merely', 'asking', 'whether', 'existance', 'israeli', 'citicens', 'wb', 'gaza', 'invalidates', 'individuals', 'right', 'live', 'eloquently', 'put', 'human', 'right', 'get', 'back', 'question', 'law', 'used', 'territories', 'later', 'also', 'adressed', 'question', 'israelis', 'also', 'human', 'rights', 'expect', 'tell', 'master', 'wisdom', 'explain', 'point', 'post', 'responded', 'point', 'since', 'israel', 'occupying', 'automatically', 'depriving', 'rights', 'occupied', 'palestineans', 'exactly', 'similar', 'automatic', 'deprivation', 'killer', 'right', 'life', 'society', 'state', 'deprive', 'citizens', 'human', 'rights', 'actions', 'tell', 'human', 'living', 'today', 'rights', 'conjugtion', 'group', 'people', 'occupies', 'others', 'territories', 'rule', 'force', 'group', 'would', 'willingly', 'unwillingly', 'deprived', 'rights', 'right', 'live', 'nice', 'swedish', 'government', 'group', 'people', 'rule', 'force', 'give', 'right', 'kill', 'consider', 'posed', ' ...

# %%
from gensim.models import Word2Vec

model = Word2Vec(sentences=tokens, vector_size=100, window=5, min_count=1, workers=4)

# %%
def get_sentences(content):
    sentence_endings_pattern = re.compile(r'(?<!\w\.\w.)(?<!\w\. \w.)(?<![A-Z][a-z]\.)(?<!\s\.\s)(?<=\.|\?|\!)\s(?![A-Z][A-Za-z]\.)(?!\w\. \w.)|(?<![,])\n(?![a-zA-Z0-9])')
    sentences = sentence_endings_pattern.split(content)

    sentences = [sentence.strip() for sentence in sentences if sentence.strip()]

    sentences_included_key_value = []

    for sentence in sentences:
        key_value_pattern = re.compile(r'[A-Z](\w+-)*\w+(\s\w+)*:[ ]*([\W\w]+[ ,])+(?!,\n)')
        if key_value_pattern.match(sentence):
            add_sentence = re.split(r'(?<!,)\n', sentence)
            sentences_included_key_value.extend(add_sentence)
        else:
            sentences_included_key_value.append(sentence)
    # sentences = [sentence.replace('\n', ' ') for sentence in sentences]
    return sentences_included_key_value

def tokenize_sentence(sentence):
    pattern = r'\+?\d[\d\-\(\)\s]{7,}\d' \
              r'|\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b' \
              r'|\b(?:Mr|Ms|Mrs|Dr|Prof|St)\.\s[A-Z][a-z]+' \
              r'|\b\d{1,2}:\d{2}\s?(?:[AaPp]\.?[Mm]\.?)\b' \
              r'|\w+|[^\w\s]'
    tokens = re.findall(pattern, sentence)
    tokens = [token.lower() for token in tokens]
    return tokens

# %%
import numpy as np

def vectorize_text(text, model):
    sentences = get_sentences(text)
    sentence_vectors = []
    
    for sentence in sentences:
        cleaned_text = clean_text(sentence)
        tokens = tokenize_sentence(cleaned_text)
        if len(tokens) == 0:
            continue
        word_vectors = [model.wv[word] if word in model.wv else np.zeros(100) for word in tokens]
        sentence_vector = np.mean(word_vectors, axis=0)
        sentence_vectors.append(sentence_vector)
        
    text_vector = np.mean(sentence_vectors, axis=0)
    
    return text_vector

# %%
text = "programs applications developing. Sentence"
file_tsv_content = {}

vector = vectorize_text(text, model)
print(len(vector))
print(vector)
# Out:
# 100
# [-0.13126607  0.8730702  -0.06724253 -0.885519    0.08366035 -0.30814037
#   0.35347325  0.903188   -0.16618164  0.36020273 -0.7230122  -0.68214893
#  -0.6995809  -0.37656865 -0.41267174 -0.03892402 -0.4163221   0.25145212
#   0.07673503 -0.16314605  0.9750533   0.09192957  0.6985528  -0.32583922
#  -0.6530629   0.65714455  1.0465605  -0.56862974  0.21398452 -0.22796029
#   0.19867368 -0.3149768  -0.14391652  0.18632062  0.3421592   0.24810258
#  -0.03822811 -0.5836861   0.19549377 -1.2125963   0.95326644 -0.6653902
#  -0.42790714 -0.10863309  0.40729508  0.0820406  -0.9431194  -0.0998101
#  -0.5804617   0.02275422 -0.5076728  -0.47001517  0.15881845 -0.04672308
#  -0.6333916  -0.14354447  0.3217734  -0.22995335 -0.96305084 -0.31937885
#   0.5656536   0.36967504 -0.19960733  0.10369359 -0.21936794  0.32454956
#   0.4123906   0.09131682 -0.10854468 -0.17188214 -1.2623756  -0.4196571
#   0.12608686 -0.2406549  -0.22845912  0.16012797 -0.07090542 -0.27815485
#   0.03591631  0.6676295   0.25190914 -0.63243634 -0.14109948 -0.21383509
#   0.32485723  0.16245082  0.09587909 -0.08104709 -0.5249963   0.04560795
#   0.75794506  0.4698695   0.08239424  0.01976376  0.79197115  0.02049144
#   0.15654378 -0.24040774 -0.40744928  0.57928526]

# %% [markdown]
# programs = applications, developing (programming)
# interface, buggy, functions, UNIX, code, signals, Internet
# people, Canada, sport, tatoo
#
#
# email = phone, FAX
# address, message, contact
# team, games, baseball
#
# lecture = seminar, courses,
# education, laboratories, conference
# situation, comments, season

# %%
from scipy.spatial.distance import cosine

def cosine_similarity(vector_a, vector_b):
    return 1 - cosine(vector_a, vector_b)

def calculate_distances(word, similar_words, domain_words, different_words, model, cosine_similarity_function):
    word_vector = model.wv[word]
    distances = []
    
    for group_name, words in [('Похожие слова', similar_words), 
                              ('Слова из той же области', domain_words), 
                              ('Совершенно другие слова', different_words)]:
        for w in words:
            if w in model.wv:
                distance = cosine_similarity_function(word_vector, model.wv[w])
                distances.append((group_name, w, distance))
    
    return sorted(distances, key=lambda x: x[2], reverse=True)

# %%
similar_words = ["applications", "developing"]
domain_words = ["interface", "buggy", "functions", "UNIX", "code", "signals", "Internet"]
different_words = ["people", "Canada", "sport", "tatoo"]

distances = calculate_distances('programs', similar_words, domain_words, different_words, model, cosine_similarity)

for group, word, distance in distances:
    print(f"{group}: {word} - Косинусное сходство: {distance:.4f}")
# Out:
# Похожие слова: applications - Косинусное сходство: 0.9297
# Слова из той же области: interface - Косинусное сходство: 0.8781
# Слова из той же области: functions - Косинусное сходство: 0.8515
# Слова из той же области: code - Косинусное сходство: 0.7499
# Похожие слова: developing - Косинусное сходство: 0.7332
# Слова из той же области: signals - Косинусное сходство: 0.7328
# Слова из той же области: buggy - Косинусное сходство: 0.7085
# Совершенно другие слова: sport - Косинусное сходство: 0.6177
# Совершенно другие слова: people - Косинусное сходство: 0.3908
# Совершенно другие слова: tatoo - Косинусное сходство: 0.3477

# %%
similar_words = ["address", "FAX"]
domain_words = ["phone", "message", "contact"]
different_words = ["team", "games", "baseball"]

distances = calculate_distances('email', similar_words, domain_words, different_words, model, cosine_similarity)

for group, word, distance in distances:
    print(f"{group}: {word} - Косинусное сходство: {distance:.4f}")
# Out:
# Слова из той же области: contact - Косинусное сходство: 0.9125
# Похожие слова: address - Косинусное сходство: 0.8907
# Слова из той же области: phone - Косинусное сходство: 0.7829
# Слова из той же области: message - Косинусное сходство: 0.7118
# Совершенно другие слова: baseball - Косинусное сходство: 0.2654
# Совершенно другие слова: games - Косинусное сходство: 0.1018
# Совершенно другие слова: team - Косинусное сходство: 0.0334

# %%
similar_words = ["seminar", "courses"]
domain_words = ["education", "laboratories", "conference"]
different_words = ["situation", "comments", "season"]

distances = calculate_distances('lecture', similar_words, domain_words, different_words, model, cosine_similarity)

for group, word, distance in distances:
    print(f"{group}: {word} - Косинусное сходство: {distance:.4f}")
# Out:
# Похожие слова: seminar - Косинусное сходство: 0.8976
# Похожие слова: courses - Косинусное сходство: 0.8141
# Слова из той же области: laboratories - Косинусное сходство: 0.7191
# Слова из той же области: education - Косинусное сходство: 0.6684
# Совершенно другие слова: situation - Косинусное сходство: 0.5917
# Совершенно другие слова: comments - Косинусное сходство: 0.5840
# Слова из той же области: conference - Косинусное сходство: 0.5772
# Совершенно другие слова: season - Косинусное сходство: 0.4353

# %%
import numpy as np

def cosine_similarity_manual(vector_a, vector_b):
    dot_product = np.dot(vector_a, vector_b)
    norm_a = np.linalg.norm(vector_a)
    norm_b = np.linalg.norm(vector_b)
    return dot_product / (norm_a * norm_b)

# %%
similar_words = ["seminar", "courses"]
domain_words = ["education", "laboratories", "conference"]
different_words = ["situation", "comments", "season"]

distances = calculate_distances('lecture', similar_words, domain_words, different_words, model, cosine_similarity_manual)

for group, word, distance in distances:
    print(f"{group}: {word} - Косинусное сходство: {distance:.4f}")
# Out:
# Похожие слова: seminar - Косинусное сходство: 0.8976
# Похожие слова: courses - Косинусное сходство: 0.8141
# Слова из той же области: laboratories - Косинусное сходство: 0.7191
# Слова из той же области: education - Косинусное сходство: 0.6684
# Совершенно другие слова: situation - Косинусное сходство: 0.5917
# Совершенно другие слова: comments - Косинусное сходство: 0.5840
# Слова из той же области: conference - Косинусное сходство: 0.5772
# Совершенно другие слова: season - Косинусное сходство: 0.4353

# %%
def read_content(file_path):
    filename = file_path.split('/')[-1]
    try:
        with open(file_path, encoding="ISO-8859-1") as file:
            content = file.read()
            return content, filename
    except Exception as e:
        print(f"Couldn't read file {filename}: {e}")
        return None

def vectorize_file(file_path):
    content, filename = read_content(file_path)
    vector = vectorize_text(content, model)
    
    vector_str = "\t".join([str(component) for component in vector])
    result_line = f"{filename}\t{vector_str}"
    
    return result_line

def vectorize_directory(directory_path, file_name):
    all_lines = []
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            file_path = os.path.join(root, file)
            line = vectorize_file(file_path)
            all_lines.append(line)
            
    tsv_filepath = os.path.join('..', 'assets', 'annotated-corpus', file_name + '.tsv')

    os.makedirs(os.path.dirname(tsv_filepath), exist_ok=True)

    with open(tsv_filepath, 'w') as f:
        f.write("\n".join(all_lines))

# %%
dataset_path = "../../dataset/20news-bydate-test"

vectorize_directory(dataset_path, 'test')

# %%
dataset_path = "../../dataset/20news-bydate-train"

vectorize_directory(dataset_path, 'train')
